# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv("C:\\Users\\AkankshaAmarendra\\PycharmProjects\\pythonProject1\\canada_per_capita_income.csv")

# %%
df.head(3)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per Capita income')
df.rename(columns={'per capita income (US$)': 'per_capita_income_USD'}, inplace=True)
plt.scatter(df.year, df.per_capita_income_USD,color='red',marker='x')

# %%
model.fit(df[[income_USD'])
# Out:
# LinearRegression()

# %%
years = ([[2024],[2025]])
model.predict(years)
# Out:
# C:\Users\AkankshaAmarendra\PycharmProjects\pythonProject1\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([44602.55439531, 45431.01947053])
